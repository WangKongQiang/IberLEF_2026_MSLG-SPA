# %% [markdown]
# 给你一段完整的 Python 脚本，可以把 MSLG_SPA_train.txt 转换成你需要的格式（Source_language_sentence\tTarget_language_sentence\n），并输出为 MSLG_to_SPA.txt。
#
# 我按照常见的 MSLG SPA 数据格式（每两行一对：源句 + 目标句）来写，如果你的格式稍有不同我也可以帮你改。

# %%
input_file = "MSLG_SPA_train.txt"
output_file = "dataset/MSLG_to_SPA.txt"

with open(input_file, "r", encoding="utf-8") as f:
    lines = f.readlines()

pairs = []

# 跳过表头（第一行）
for line in lines[1:]:
    parts = line.strip().split("\t")
    
    # 确保格式正确（3列：ID, MSLG, SPA）
    if len(parts) >= 3:
        source = parts[1].strip()  # MSLG
        target = parts[2].strip()  # SPA
        pairs.append(f"{source}\t{target}\n")

# 写入新文件
with open(output_file, "w", encoding="utf-8") as f:
    f.writelines(pairs)

print(f"转换完成，共生成 {len(pairs)} 条数据，保存为 {output_file}")
# Out:
# 转换完成，共生成 490 条数据，保存为 dataset/MSLG_to_SPA.txt

# %% [markdown]
# 给你一段完整的 Python 脚本，可以把 MSLG_SPA_train.txt 转换成你需要的格式（Source_language_sentence\tTarget_language_sentence\n），并输出为 SPA_to_MSLG.txt。
#
# 我按照常见的 SPA MSLG 数据格式（每两行一对：源句 + 目标句）来写，如果你的格式稍有不同我也可以帮你改。

# %%
input_file = "MSLG_SPA_train.txt"
output_file = "dataset/SPA_to_MSLG.txt"

with open(input_file, "r", encoding="utf-8") as f:
    lines = f.readlines()

pairs = []

# 跳过表头（第一行）
for line in lines[1:]:
    parts = line.strip().split("\t")
    
    # 确保格式正确（3列：ID, MSLG, SPA）
    if len(parts) >= 3:
        source = parts[2].strip()   # SPA
        target = parts[1].strip()   # MSLG
        pairs.append(f"{source}\t{target}\n")

# 写入新文件
with open(output_file, "w", encoding="utf-8") as f:
    f.writelines(pairs)

print(f"转换完成，共生成 {len(pairs)} 条数据，保存为 {output_file}")
# Out:
# 转换完成，共生成 490 条数据，保存为 dataset/SPA_to_MSLG.txt
